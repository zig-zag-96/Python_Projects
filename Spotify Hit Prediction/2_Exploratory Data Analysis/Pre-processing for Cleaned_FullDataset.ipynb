# %% [markdown]
# In this notebook I will remove categorical variables or encode them, drop the unnecesary columns from the dataset, and scale the data so it is standardized.

# %%
#import modules

import pandas as pd
import numpy as np

from sklearn.preprocessing import scale

# %%
pwd
# Out:
# 'C:\\Users\\ziggy\\Springboard\\Python_Projects\\Spotify Hit Prediction\\2_Exploratory Data Analysis'

# %%
df = pd.read_csv('Cleaned_FullDataset', index_col=0)

# %%
df.head()
# Out:
#                         Title                        Artist  \
# 0         hanging by a moment                     lifehouse
# 1                     fallin’                   alicia keys
# 2                 all for you                 janet jackson
# 3  drops of jupiter (tell me)                         train
# 4                    i’m real  jennifer lopez feat. ja rule
#
#                       URI  danceability  energy   key  loudness  mode  \
# 0  0wqOReZDnrefefEsrIGeR4         0.541   0.864   1.0    -4.915   1.0
# 1  0KQx6HOpJueiSkztcS0r7D         0.652   0.609  11.0    -7.519   0.0
# 2  5X8kkUaUlAyAUr9TYqDFTH         0.753   0.934   2.0    -3.011   1.0
# 3  2hKdd3qO7cWr2Jo0Bcs0MA         0.481   0.638   0.0    -5.862   1.0
# 4  6MLsahMK3VvH9NUwXOktdS         0.708   0.587  11.0    -7.930   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0357       0.00118           0.00000    0.0896    0.435  124.557
# 1       0.0370       0.26300           0.00101    0.2330    0.482   95.986
# 2       0.0736       0.01740           0.06500    0.1280    0.730  113.525
# 3       0.0276       0.15300           0.00000    0.1540    0.497   79.064
# 4       0.1510       0.27300           0.00000    0.0718    0.554   83.460
#
#    duration_ms  time_signature  Target
# 0     216067.0             4.0       1
# 1     210200.0             3.0       1
# 2     329933.0             3.0       1
# 3     259933.0             4.0       1
# 4     262133.0             4.0       1

# %% [markdown]
# Removing categorical features: Title, Artists  and setting index = URI. Creating dummies for key and time signature.

# %%
data = df.drop(columns=['Title','Artist'],axis=1)

# %%
#Let's convert the duration from miliseconds to seconds
data['duration']=data['duration_ms'].apply(lambda x: round(x/1000))
data.drop(columns='duration_ms', inplace=True, axis=1)

# %%
data = pd.get_dummies(data=data,columns=['key','time_signature'])

# %%
#Creating a new dataframe, `data_scale` from `data` whilst setting the index to URI
data_scale = data.set_index('URI')
#Saving the URI labels (using the index attribute of data_uri) into the variable data_scale_index
data_scale_index = data_scale.index
#Save the column names (using the `columns` attribute) of `data_scale` into the variable 'state_summary_columns'
data_scale_columns = data_scale.columns
data_scale.head()
# Out:
#                         danceability  energy  loudness  mode  speechiness  \
# URI
# 0wqOReZDnrefefEsrIGeR4         0.541   0.864    -4.915   1.0       0.0357
# 0KQx6HOpJueiSkztcS0r7D         0.652   0.609    -7.519   0.0       0.0370
# 5X8kkUaUlAyAUr9TYqDFTH         0.753   0.934    -3.011   1.0       0.0736
# 2hKdd3qO7cWr2Jo0Bcs0MA         0.481   0.638    -5.862   1.0       0.0276
# 6MLsahMK3VvH9NUwXOktdS         0.708   0.587    -7.930   0.0       0.1510
#
#                         acousticness  instrumentalness  liveness  valence  \
# URI
# 0wqOReZDnrefefEsrIGeR4       0.00118           0.00000    0.0896    0.435
# 0KQx6HOpJueiSkztcS0r7D       0.26300           0.00101    0.2330    0.482
# 5X8kkUaUlAyAUr9TYqDFTH       0.01740           0.06500    0.1280    0.730
# 2hKdd3qO7cWr2Jo0Bcs0MA       0.15300           0.00000    0.1540    0.497
# 6MLsahMK3VvH9NUwXOktdS       0.27300           0.00000    0.0718    0.554
#
#                           tempo  ...  key_7.0  key_8.0  key_9.0  key_10.0  \
# URI                              ...
# 0wqOReZDnrefefEsrIGeR4  124.557  ...        0        0        0         0
# 0KQx6HOpJueiSkztcS0r7D   95.986  ...        0        0        0         0
# 5X8kkUaUlAyAUr9TYqDFTH  113.525  ...        0        0        0         0
# 2hKdd3qO7cWr2Jo0Bcs0MA   79.064  ...        0        0        0         0
# 6MLsahMK3VvH9NUwXOktdS   83.460  ...        0        0        0         0
#
#                         key_11.0  time_signature_0.0  time_signature_1.0  \
# URI
# 0wqOReZDnrefefEsrIGeR4         0                   0                   0
# 0KQx6HOpJueiSkztcS0r7D         1                   0                   0
# 5X8kkUaUlAyAUr9TYqDFTH         0                   0                   0
# 2hKdd3qO7cWr2Jo0Bcs0MA         0                   0                   0
# 6MLsahMK3VvH9NUwXOktdS         1                   0                   0
#
#                         time_signature_3.0  time_signature_4.0  \
# URI
# 0wqOReZDnrefefEsrIGeR4                   0                   1
# 0KQx6HOpJueiSkztcS0r7D                   1                   0
# 5X8kkUaUlAyAUr9TYqDFTH                   1                   0
# 2hKdd3qO7cWr2Jo0Bcs0MA                   0                   1
# 6MLsahMK3VvH9NUwXOktdS                   0                   1
#
#                         time_signature_5.0
# URI
# 0wqOReZDnrefefEsrIGeR4                   0
# 0KQx6HOpJueiSkztcS0r7D                   0
# 5X8kkUaUlAyAUr9TYqDFTH                   0
# 2hKdd3qO7cWr2Jo0Bcs0MA                   0
# 6MLsahMK3VvH9NUwXOktdS                   0
#
# [5 rows x 29 columns]

# %%
data_scale=scale(data_scale)

# %%
#creating a df from the scaled data (numpy array) and adding back the column names
data_scale_df = pd.DataFrame(data_scale, columns=data_scale_columns)
data_scale_df.head()
# Out:
#    danceability    energy  loudness      mode  speechiness  acousticness  \
# 0     -0.050561  1.105273  0.784208  0.723863    -0.521584     -1.029989
# 1      0.498560  0.190889  0.437858 -1.381477    -0.515065     -0.305557
# 2      0.998210  1.356280  1.037453  0.723863    -0.331539     -0.985110
# 3     -0.347384  0.294877  0.658250  0.723863    -0.562200     -0.609917
# 4      0.775594  0.112001  0.383193 -1.381477     0.056574     -0.277888
#
#    instrumentalness  liveness   valence     tempo  ...  key_7.0   key_8.0  \
# 0         -0.633781 -0.640383 -0.015460  0.236671  ...  -0.3559 -0.258645
# 1         -0.631042  0.100534  0.159904 -0.673878  ...  -0.3559 -0.258645
# 2         -0.457532 -0.441979  1.085233 -0.114915  ...  -0.3559 -0.258645
# 3         -0.633781 -0.307642  0.215872 -1.213177  ...  -0.3559 -0.258645
# 4         -0.633781 -0.732352  0.428548 -1.073077  ...  -0.3559 -0.258645
#
#     key_9.0  key_10.0  key_11.0  time_signature_0.0  time_signature_1.0  \
# 0 -0.326465 -0.270804 -0.285080           -0.062433           -0.122227
# 1 -0.326465 -0.270804  3.507784           -0.062433           -0.122227
# 2 -0.326465 -0.270804 -0.285080           -0.062433           -0.122227
# 3 -0.326465 -0.270804 -0.285080           -0.062433           -0.122227
# 4 -0.326465 -0.270804  3.507784           -0.062433           -0.122227
#
#    time_signature_3.0  time_signature_4.0  time_signature_5.0
# 0           -0.372538            0.455863           -0.180591
# 1            2.684291           -2.193640           -0.180591
# 2            2.684291           -2.193640           -0.180591
# 3           -0.372538            0.455863           -0.180591
# 4           -0.372538            0.455863           -0.180591
#
# [5 rows x 29 columns]

# %%
#verifying the mean scaling
data_scale_df.mean()
# Out:
# danceability          5.925484e-17
# energy               -1.261032e-17
# loudness              2.573664e-16
# mode                  1.013471e-15
# speechiness           1.810200e-16
# acousticness         -4.104788e-17
# instrumentalness     -5.033590e-15
# liveness              2.752750e-16
# valence               1.486989e-16
# tempo                 1.055391e-17
# Target               -1.296684e-14
# duration              3.168665e-17
# key_0.0               9.263182e-16
# key_1.0               4.353289e-15
# key_2.0               1.930666e-16
# key_3.0              -3.784673e-16
# key_4.0               2.043284e-15
# key_5.0              -4.956757e-16
# key_6.0              -9.561326e-17
# key_7.0               2.858618e-16
# key_8.0               3.259582e-15
# key_9.0               2.226301e-16
# key_10.0             -1.610004e-16
# key_11.0             -8.533778e-16
# time_signature_0.0    4.374665e-15
# time_signature_1.0    6.771469e-16
# time_signature_3.0   -5.201816e-15
# time_signature_4.0   -1.245187e-14
# time_signature_5.0   -4.647225e-15
# dtype: float64

# %%
data_scale_df.std()
# Out:
# danceability          1.000029
# energy                1.000029
# loudness              1.000029
# mode                  1.000029
# speechiness           1.000029
# acousticness          1.000029
# instrumentalness      1.000029
# liveness              1.000029
# valence               1.000029
# tempo                 1.000029
# Target                1.000029
# duration              1.000029
# key_0.0               1.000029
# key_1.0               1.000029
# key_2.0               1.000029
# key_3.0               1.000029
# key_4.0               1.000029
# key_5.0               1.000029
# key_6.0               1.000029
# key_7.0               1.000029
# key_8.0               1.000029
# key_9.0               1.000029
# key_10.0              1.000029
# key_11.0              1.000029
# time_signature_0.0    1.000029
# time_signature_1.0    1.000029
# time_signature_3.0    1.000029
# time_signature_4.0    1.000029
# time_signature_5.0    1.000029
# dtype: float64

# %% [markdown]
# coud be a little closer to 1... this is probably due to the fact that scale() uses the biased estimator for standard deviation (ddof=0) while std() assumes we are working with a sample and looking to estimate the population parameter. So, we need to specify that we want ddof=0.

# %%
data_scale_df.std(ddof=0)
# Out:
# danceability          1.0
# energy                1.0
# loudness              1.0
# mode                  1.0
# speechiness           1.0
# acousticness          1.0
# instrumentalness      1.0
# liveness              1.0
# valence               1.0
# tempo                 1.0
# Target                1.0
# duration              1.0
# key_0.0               1.0
# key_1.0               1.0
# key_2.0               1.0
# key_3.0               1.0
# key_4.0               1.0
# key_5.0               1.0
# key_6.0               1.0
# key_7.0               1.0
# key_8.0               1.0
# key_9.0               1.0
# key_10.0              1.0
# key_11.0              1.0
# time_signature_0.0    1.0
# time_signature_1.0    1.0
# time_signature_3.0    1.0
# time_signature_4.0    1.0
# time_signature_5.0    1.0
# dtype: float64
